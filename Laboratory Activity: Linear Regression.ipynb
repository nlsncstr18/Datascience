# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import preprocessing

# %%
train = pd.read_csv('C:\\ProgramData\\Anaconda3\\train.csv')
here = train[['Utilities','Neighborhood','BldgType','Heating','BsmtHalfBath','HalfBath','EnclosedPorch']].head(1500)

here
# Out:
#      Utilities Neighborhood BldgType Heating  BsmtHalfBath  HalfBath  \
# 0       AllPub      CollgCr     1Fam    GasA             0         1
# 1       AllPub      Veenker     1Fam    GasA             1         0
# 2       AllPub      CollgCr     1Fam    GasA             0         1
# 3       AllPub      Crawfor     1Fam    GasA             0         0
# 4       AllPub      NoRidge     1Fam    GasA             0         1
# 5       AllPub      Mitchel     1Fam    GasA             0         1
# 6       AllPub      Somerst     1Fam    GasA             0         0
# 7       AllPub       NWAmes     1Fam    GasA             0         1
# 8       AllPub      OldTown     1Fam    GasA             0         0
# 9       AllPub      BrkSide   2fmCon    GasA             0         0
# 10      AllPub       Sawyer     1Fam    GasA             0         0
# 11      AllPub      NridgHt     1Fam    GasA             0         0
# 12      AllPub       Sawyer     1Fam    GasA             0         0
# ...

# %%
#hakdog['Utilities'].isnull()
#hakdog['Neighborhood'].isnull()
#hakdog['BldgType'].isnull()
#hakdog['Heating'].isnull()
#hakdog['BsmtHalfBath'].isnull()
#hakdog['HalfBath'].isnull()
#hakdog['EnclosedPorch'].isnull()

# %%
en = preprocessing.LabelEncoder()
en.fit(here['Utilities'])
encoded_data = en.transform(here['Utilities'])
encoded_data
here['Utilities'] = encoded_data

en = preprocessing.LabelEncoder()
en.fit(here['Neighborhood'])
encoded_data = en.transform(here['Neighborhood'])
encoded_data
here['Neighborhood'] = encoded_data

en = preprocessing.LabelEncoder()
en.fit(here['BldgType'])
encoded_data = en.transform(here['BldgType'])
encoded_data
here['BldgType'] = encoded_data

en = preprocessing.LabelEncoder()
en.fit(here['Heating'])
encoded_data = en.transform(here['Heating'])
encoded_data
here['Heating'] = encoded_data

en = preprocessing.LabelEncoder()
en.fit(here['BsmtHalfBath'])
encoded_data = en.transform(here['BsmtHalfBath'])
encoded_data
here['BsmtHalfBath'] = encoded_data


en = preprocessing.LabelEncoder()
en.fit(here['HalfBath'])
encoded_data = en.transform(here['HalfBath'])
encoded_data
here['HalfBath'] = encoded_data

en = preprocessing.LabelEncoder()
en.fit(here['EnclosedPorch'])
encoded_data = en.transform(here['EnclosedPorch'])
encoded_data
here['EnclosedPorch'] = encoded_data


hakdog = here[['Utilities', 'Neighborhood', 'BldgType', 'Heating', 'BsmtHalfBath', 'HalfBath', 'EnclosedPorch' ]]
hakdog.head(21)
# Out:
#     Utilities  Neighborhood  BldgType  Heating  BsmtHalfBath  HalfBath  \
# 0           0             5         0        1             0         1
# 1           0            24         0        1             1         0
# 2           0             5         0        1             0         1
# 3           0             6         0        1             0         0
# 4           0            15         0        1             0         1
# 5           0            11         0        1             0         1
# 6           0            21         0        1             0         0
# 7           0            14         0        1             0         1
# 8           0            17         0        1             0         0
# 9           0             3         1        1             0         0
# 10          0            19         0        1             0         0
# 11          0            16         0        1             0         0
# ...

# %%
normalized = preprocessing.normalize(here, norm = 'l1')
print(normalized)
# Out:
# [[0.         0.71428571 0.         ... 0.         0.14285714 0.        ]
#  [0.         0.92307692 0.         ... 0.03846154 0.         0.        ]
#  [0.         0.71428571 0.         ... 0.         0.14285714 0.        ]
#  ...
#  [0.         0.85714286 0.         ... 0.         0.         0.        ]
#  [0.         0.23529412 0.         ... 0.         0.         0.74509804]
#  [0.         0.77777778 0.         ... 0.         0.11111111 0.        ]]

# %%
train = pd.read_csv('C:\\ProgramData\\Anaconda3\\train.csv')
sales = train[['SalePrice']].head(21)
sales
# Out:
#     SalePrice
# 0      208500
# 1      181500
# 2      223500
# 3      140000
# 4      250000
# 5      143000
# 6      307000
# 7      200000
# 8      129900
# 9      118000
# 10     129500
# 11     345000
# 12     144000
# 13     279500
# 14     157000
# 15     132000
# 16     149000
# 17      90000
# 18     159000
# 19     139000
# 20     325300

# %%
x = here['Neighborhood']
y = sales['SalePrice']

df = pd.DataFrame({'x':x, 'y':y})
print(this.head(20))
# Out:
#      x         y         xycov        xvar
# 0    5  208500.0 -1.477208e+05   52.582365
# 1   24  181500.0 -7.787663e+04  138.030310
# 2    5  223500.0 -2.564913e+05   52.582365
# 3    6  140000.0  3.008695e+05   39.079625
# 4   15  250000.0  1.700617e+05    7.554968
# 5   11  143000.0  5.647253e+04    1.565927
# 6   21  307000.0  1.039962e+06   76.538529
# 7   14  200000.0  2.075874e+04    3.057707
# 8   17  129900.0 -2.765059e+05   22.549488
# 9    3  118000.0  6.487854e+05   85.587844
# 10  19  129500.0 -3.956625e+05   45.544009
# 11  16  345000.0  5.880530e+05   14.052228
# 12  19  144000.0 -2.978074e+05   45.544009
# 13   5  279500.0 -6.625680e+05   52.582365
# 14  12  157000.0  7.824785e+03    0.063187
# 15   3  132000.0  5.192662e+05   85.587844
# 16  12  149000.0  9.835744e+03    0.063187
# 17  19   90000.0 -6.622334e+05   45.544009
# 18  20  159000.0 -2.257065e+05   60.041269
# 19  12  139000.0  1.234944e+04    0.063187

# %%
xmean = np.mean(x)
ymean = np.mean(y)

df['xycov'] = ((df['x'] -xmean) * (df['y']-ymean))
df['xvar'] = (df['x'] - xmean)**2

beta = df['xycov'].sum()/df['xvar'].sum()
alpha = ymean - (beta * xmean)

print(beta)
print(alpha)
# Out:
# 16.7890774535822
# 187922.8822310288

# %%
#y = bx +a
ypred = beta*x + alpha
ypred
# Out:
# 0     188006.827618
# 1     188325.820090
# 2     188006.827618
# 3     188023.616696
# 4     188174.718393
# 5     188107.562083
# 6     188275.452858
# 7     188157.929315
# 8     188208.296548
# 9     187973.249463
# 10    188241.874703
# 11    188191.507470
# 12    188241.874703
# 13    188006.827618
# 14    188124.351160
# 15    187973.249463
# 16    188124.351160
# 17    188241.874703
# 18    188258.663780
# 19    188124.351160
# Name: Neighborhood, dtype: float64

# %%
#plotting
plt.figure(figsize = (12 , 6))
plt.plot(x,y, 'bo')
plt.plot(x,ypred, 'ro')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Actual vs Predicted')
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-91d862a25880> in <module>
#       1 #plotting
#       2 plt.figure(figsize = (12 , 6))
# ----> 3 plt.plot(x,y, 'bo')
#       4 plt.plot(x,ypred, 'ro')
#       5 plt.xlabel('X')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...
